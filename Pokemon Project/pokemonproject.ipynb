# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/2023-2024 School Year/Machine Learning /Data /pokemons.csv')

# %%
df.columns
# Out:
# Index(['id', 'name', 'rank', 'generation', 'evolves_from', 'type1', 'type2',
#        'hp', 'atk', 'def', 'spatk', 'spdef', 'speed', 'total', 'height',
#        'weight', 'abilities', 'desc'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have a DataFrame 'df' with the specified columns

# Select the attributes to compare
attributes = ['hp', 'atk', 'def', 'spatk', 'spdef', 'speed']

# Create a list of unique generations
generations = df['generation'].unique()

# Set up the figure and axis for the radar chart
num_attributes = len(attributes)

for generation in generations:
    generation_data = df[df['generation'] == generation]

    # Create a radar chart for each generation
    fig, ax = plt.subplots(subplot_kw=dict(polar=True), figsize=(8, 8))

    stats = generation_data[attributes].mean().values
    angles = np.linspace(0, 2 * np.pi, num_attributes, endpoint=False)
    stats = np.concatenate((stats, [stats[0]]))  # Close the radar chart
    angles = np.concatenate((angles, [angles[0]]))  # Close the radar chart

    ax.fill(angles, stats, alpha=0.5, color='b')
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(attributes)

    ax.set_title(f'Radar Chart of Pokémon Stats for Generation {generation}')

    # Display the radar chart for each generation
    plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Select the attributes to compare
attributes = ['hp', 'atk', 'def', 'spatk', 'spdef', 'speed']
generations = df['generation'].unique()

# ChatGPT set up the figure with subplots for radar charts
num_attributes = len(attributes)
num_generations = len(generations)
fig, axes = plt.subplots(1, num_generations, subplot_kw=dict(polar=True), figsize=(20, 5))

for i, generation in enumerate(generations):
    generation_data = df[df['generation'] == generation]

    ax = axes[i]
    stats = generation_data[attributes].mean().values
    angles = np.linspace(0, 2 * np.pi, num_attributes, endpoint=False)
    stats = np.concatenate((stats, [stats[0]]))  # Close the radar chart
    angles = np.concatenate((angles, [angles[0]]))  # Close the radar chart

    ax.fill(angles, stats, alpha=0.5, color='b')
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(attributes)
    ax.set_title(f'Generation {generation}')

fig.suptitle('Radar Charts of Pokémon Stats by Generation', fontsize=16)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Select the attributes to compare
attributes = ['hp','atk','def']
generations = df['generation'].unique()

# ChatGPT set up the figure with subplots for radar charts
num_attributes = len(attributes)
num_generations = len(generations)
fig, axes = plt.subplots(1, num_generations, subplot_kw=dict(polar=True), figsize=(20, 5))

for i, generation in enumerate(generations):
    generation_data = df[df['generation'] == generation]

    ax = axes[i]
    stats = generation_data[attributes].mean().values
    angles = np.linspace(0, 2 * np.pi, num_attributes, endpoint=False)
    stats = np.concatenate((stats, [stats[0]]))  # Close the radar chart
    angles = np.concatenate((angles, [angles[0]]))  # Close the radar chart

    ax.fill(angles, stats, alpha=0.5, color='b')
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(attributes)
    ax.set_title(f'Generation {generation}')

fig.suptitle('Radar Charts of Pokémon Stats by Generation', fontsize=16)
plt.tight_layout()
plt.show()

# %%
df.sort_values(by = 'hp', ascending = False)
# Out:
#       id       name       rank       generation evolves_from    type1   type2  \
# 241  242    blissey   ordinary    generation-ii      chansey   normal    None
# 112  113    chansey   ordinary     generation-i      happiny   normal    None
# 798  799   guzzlord   ordinary   generation-vii      nothing     dark  dragon
# 894  895  regidrago  legendary  generation-viii      nothing   dragon    None
# 201  202  wobbuffet   ordinary    generation-ii       wynaut  psychic    None
# ..   ...        ...        ...              ...          ...      ...     ...
# 438  439    mime-jr       baby    generation-iv      nothing  psychic   fairy
# 354  355    duskull   ordinary   generation-iii      nothing    ghost    None
# 49    50    diglett   ordinary     generation-i      nothing   ground    None
# 959  960    wiglett   ordinary    generation-ix      nothing    water    None
# 291  292   shedinja   ordinary   generation-iii      nincada      bug   ghost
#
# ...

# %%
# !pip install seaborn
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['id', 'name', 'rank', 'generation', 'evolves_from', 'type1', 'type2',
#        'hp', 'atk', 'def', 'spatk', 'spdef', 'speed', 'total', 'height',
#        'weight', 'abilities', 'desc'],
#       dtype='object')

# %%
x = df['height']
y = df['hp']
sns.scatterplot (x=x, y=y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = df['weight']
y = df['hp']
sns.scatterplot (x=x, y=y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = df['height']
y = df['atk']
sns.scatterplot (x=x, y=y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = df['weight']
y = df['atk']
sns.scatterplot (x=x, y=y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Group by 'generation' and calculate the mean of 'atk'
mean_atk_by_generation = df.groupby('generation')['atk'].mean()

# Extract the 'generation' values and the calculated mean attack values
x = mean_atk_by_generation.index
y = mean_atk_by_generation.values

plt.figure(figsize=(15, 6))
sns.barplot(x=x, y=y)
plt.xlabel('Generation')
plt.ylabel('Mean Attack (atk)')
plt.title('Scatter Plot of Generation vs. Mean Attack')
plt.show()

# %%
# Group by 'generation' and calculate the mean of 'atk'
mean_atk_by_generation = df.groupby('generation')['hp'].mean()

# Extract the 'generation' values and the calculated mean attack values
x = mean_atk_by_generation.index
y = mean_atk_by_generation.values

plt.figure(figsize=(15, 6))
sns.barplot(x=x, y=y)
plt.xlabel('Generation')
plt.ylabel('Mean Health (hp)')
plt.title('Scatter Plot of Generation vs. Mean Health')
plt.show()

# %%
# Group by 'generation' and calculate the mean of 'atk'
mean_atk_by_generation = df.groupby('generation')['def'].mean()

# Extract the 'generation' values and the calculated mean attack values
x = mean_atk_by_generation.index
y = mean_atk_by_generation.values

plt.figure(figsize=(15, 6))
sns.barplot(x=x, y=y)
plt.xlabel('Generation')
plt.ylabel('Mean Defense')
plt.title('Scatter Plot of Generation vs. Mean Defense')
plt.show()

# %%
mean_atk_by_generation = df.groupby('generation')['sentiment'].mean()

x = mean_atk_by_generation.index
y = mean_atk_by_generation.values

plt.figure(figsize=(15, 6))
sns.barplot(x=x, y=y)
plt.xlabel('Generation')
plt.ylabel('Mean Sentiment')
plt.title('Scatter Plot of Generation vs. Mean Sentiment')
plt.show()

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from textblob import TextBlob

# Download NLTK data (if not already downloaded)
nltk.download('punkt')
nltk.download('stopwords')

# Function to perform keyword extraction
def extract_keywords(text):
    words = word_tokenize(text.lower())  # Convert to lowercase
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word.isalnum() and word not in stop_words]
    word_freq = nltk.FreqDist(filtered_words)
    keywords = [word for word, freq in word_freq.most_common(5)]  # Adjust the number as needed
    return keywords

# Function to perform sentiment analysis
def analyze_sentiment(text):
    analysis = TextBlob(text)
    sentiment = analysis.sentiment.polarity  # Polarity ranges from -1 (negative) to 1 (positive)
    return sentiment

# Apply keyword extraction and sentiment analysis to the 'desc' column
df['keywords'] = df['desc'].apply(extract_keywords)
df['sentiment'] = df['desc'].apply(analyze_sentiment)

# Add the sentiment scores to a new column 'sentiment_score'
df['sentiment_score'] = df['sentiment']

# Print the DataFrame with keywords and the new 'sentiment_score' column
print(df[['name', 'desc', 'keywords', 'sentiment_score']])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#              name                                               desc  \
# 0       bulbasaur  A strange seed was planted on its back at birt...
# 1         ivysaur  When the bulb on its back grows large, it appe...
# 2        venusaur  The plant blooms when it is absorbing solar en...
# 3      charmander  Obviously prefers hot places. When it rains, s...
# 4      charmeleon  When it swings its burning tail, it elevates t...
# ...           ...                                                ...
# 1012    sinistcha                                      Not Available
# 1013      okidogi                                      Not Available
# 1014    munkidori                                      Not Available
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = df.groupby(['type2', 'type1'])['sentiment'].mean().sort_values(ascending=False).head(10)

#ChatGPT Helped
group_names = [f'{item[0]} - {item[1]}' for item in data.index]
sentiment_scores = data.values

plt.figure(figsize=(10, 6))
plt.barh(group_names, sentiment_scores, color='lightblue')
plt.xlabel('Sentiment Score')
plt.title('Top 10 Groups by Sentiment Score')
plt.gca().invert_yaxis()  # To display the highest sentiment score at the top
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = df.groupby(['generation'])['sentiment'].mean()

#ChatGPT helped with the grouping and sorting of data
data = data.reset_index().sort_values(by='sentiment', ascending=False).groupby('generation').head(10)

#Extract the sentiment scores
sentiment_scores = data['sentiment'].values

# Create the horizontal bar plot
plt.figure(figsize=(10, 6))
plt.barh(group_names, sentiment_scores, color='lightblue')
plt.xlabel('Sentiment Score')
plt.title('Top 10 Groups by Sentiment Score (Grouped by Generation)')
plt.gca().invert_yaxis()  # To display the highest sentiment score at the top
plt.show()

# %% [markdown]
# Choosing the "best" combination of five types for Pokémon team coverage depends on various factors, including the current metagame, the specific Pokémon you have available, and your preferred battling style. However, for a balanced and versatile team, you can aim for a combination of types that collectively cover a wide range of strengths and weaknesses. Here's one such combination:
#
# **Water Type:** Water types provide excellent coverage, resistances, and versatility. They are weak to Electric and Grass types but resist Water, Fire, Ice, and Steel types.
#
# **Grass Type:** Grass types are effective against Water and Ground types, providing strong coverage against those common threats. They are weak to Fire, Ice, Poison, Flying, and Bug types.
#
# **Fire Type**: Fire types are strong against Grass, Bug, Ice, and Steel types. They have weaknesses to Water, Rock, and Ground types.
#
# **Electric Type:** Electric types are powerful offensively and have only one weakness (Ground). They resist Electric and Flying types.
#
# **Fairy Type:** Fairy types can deal with Dragon types effectively and have good resistance to Bug, Dark, and Fighting types. They are weak to Steel and Poison types.

# %%
# Assuming you have a DataFrame named 'df' with the specified columns.

# List of types to search for (in lowercase).
types_to_search = ['water', 'grass', 'fire', 'electric', 'fairy']

# Create an empty dictionary to store the top five Pokémon for each type.
top_five_pokemon_by_type = {}

# Iterate through each type and find the top five Pokémon with the highest total base stat.
for type_to_search in types_to_search:
    # Filter the DataFrame for Pokémon of the current type in either type1 or type2.
    filtered_pokemon = df[(df['type1'].str.lower() == type_to_search) | (df['type2'].str.lower() == type_to_search)]

    # Check if the filtered DataFrame is not empty.
    if not filtered_pokemon.empty:
        # Sort the DataFrame by total base stat in descending order and take the top five.
        top_five_pokemon = filtered_pokemon.sort_values(by='total', ascending=False).head(5)

        # Add the top five Pokémon for the current type to the dictionary.
        top_five_pokemon_by_type[type_to_search] = top_five_pokemon
    else:
        # Handle the case when there are no Pokémon of the current type.
        top_five_pokemon_by_type[type_to_search] = None

# Print the results.
for type_name, top_five_pokemon in top_five_pokemon_by_type.items():
    if top_five_pokemon is not None:
        print(f"Top five {type_name} Pokémon:")
        for index, row in top_five_pokemon.iterrows():
            pokemon_types = [row['type1'], row['type2']] if not pd.isna(row['type2']) else [row['type1']]
            print(f"   {row['name']} (Types: {', '.join(pokemon_types)} | Total Stats: {row['total']})")
    else:
        print(f"No {type_name} Pokémon found in the dataset.")
# Out:
# Top five water Pokémon:
#    palkia (Types: water, dragon | Total Stats: 680)
#    kyogre (Types: water, None | Total Stats: 670)
#    volcanion (Types: fire, water | Total Stats: 600)
#    manaphy (Types: water, None | Total Stats: 600)
#    walking-wake (Types: water, dragon | Total Stats: 590)
# Top five grass Pokémon:
#    shaymin (Types: grass, None | Total Stats: 600)
#    zarude (Types: dark, grass | Total Stats: 600)
#    celebi (Types: psychic, grass | Total Stats: 600)
#    iron-leaves (Types: grass, psychic | Total Stats: 590)
#    virizion (Types: grass, fighting | Total Stats: 580)
# Top five fire Pokémon:
#    reshiram (Types: dragon, fire | Total Stats: 680)
#    ho-oh (Types: fire, flying | Total Stats: 680)
#    victini (Types: psychic, fire | Total Stats: 600)
#    heatran (Types: fire, steel | Total Stats: 600)
#    volcanion (Types: fire, water | Total Stats: 600)
# Top five electric Pokémon:
#    zekrom (Types: dragon, electric | Total Stats: 680)
# ...

# %%
df['abilities'].unique()
# Out:
# array(['overgrow chlorophyll ', 'blaze solar-power ',
#        'torrent rain-dish ', 'shield-dust run-away ', 'shed-skin ',
#        'compound-eyes tinted-lens ', 'swarm sniper ',
#        'keen-eye tangled-feet big-pecks ', 'run-away guts hustle ',
#        'keen-eye sniper ', 'intimidate shed-skin unnerve ',
#        'static lightning-rod ', 'sand-veil sand-rush ',
#        'poison-point rivalry hustle ',
#        'poison-point rivalry sheer-force ',
#        'cute-charm magic-guard friend-guard ',
#        'cute-charm magic-guard unaware ', 'flash-fire drought ',
#        'cute-charm competitive friend-guard ',
#        'cute-charm competitive frisk ', 'inner-focus infiltrator ',
#        'chlorophyll run-away ', 'chlorophyll stench ',
#        'chlorophyll effect-spore ', 'effect-spore dry-skin damp ',
#        'compound-eyes tinted-lens run-away ',
#        'shield-dust tinted-lens wonder-skin ',
#        'sand-veil arena-trap sand-force ', 'pickup technician unnerve ',
# ...

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame named 'df' with the 'desc', 'type1', and 'type2' columns.
# Replace 'df' with the actual name of your DataFrame.

# Download NLTK data (if not already downloaded)
nltk.download('punkt')
nltk.download('stopwords')

# Function to perform sentiment analysis
def analyze_sentiment(text):
    analysis = TextBlob(text)
    sentiment = analysis.sentiment.polarity  # Polarity ranges from -1 (negative) to 1 (positive)
    return sentiment

# Apply sentiment analysis to the 'desc' column
df['sentiment'] = df['desc'].apply(analyze_sentiment)

# Combine 'type1' and 'type2' columns to create a new column 'combined_type'
df['combined_type'] = df['type1'] + ' / ' + df['type2']

# Calculate the top 10 mean sentiment scores by 'combined_type'
top_10_combined_types = df.groupby('combined_type')['sentiment'].mean().sort_values(ascending=False).head(10).index

# Filter the DataFrame to include only the top 10 combined types
df_top_10 = df[df['combined_type'].isin(top_10_combined_types)]

# Create a bar graph to show the mean sentiment scores for the top 10 combined types
plt.figure(figsize=(12, 6))
sns.barplot(x='combined_type', y='sentiment', data=df_top_10, order=top_10_combined_types)
plt.title('Top 10 Mean Sentiment Scores by Combined Type (type1 / type2)')
plt.xlabel('Combined Type (type1 / type2)')
plt.ylabel('Mean Sentiment Score')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with the 'name', 'sentiment', and 'total' columns.
# Replace 'df' with the actual name of your DataFrame.

def find_top_pokemon(df, num_top=5):
    # Sort the DataFrame by sentiment (in descending order) and total stats (in descending order)
    sorted_df = df.sort_values(by=['sentiment', 'total'], ascending=[False, False])

    # Get the information of the top Pokémon
    top_pokemon_info = sorted_df.iloc[:num_top]

    # Extract the relevant information for the top Pokémon
    top_pokemon_names = top_pokemon_info['name'].tolist()
    top_pokemon_sentiments = top_pokemon_info['sentiment'].tolist()
    top_pokemon_totals = top_pokemon_info['total'].tolist()

    return top_pokemon_names, top_pokemon_sentiments, top_pokemon_totals

# Example usage to show the top 5 Pokémon
top_pokemon_names, top_pokemon_sentiments, top_pokemon_totals = find_top_pokemon(df, num_top=5)

print("Top 5 Pokémon:")
for i in range(len(top_pokemon_names)):
    print(f"Name: {top_pokemon_names[i]}")
    print(f"Sentiment Score: {top_pokemon_sentiments[i]}")
    print(f"Total Stat: {top_pokemon_totals[i]}")
    print()
# Out:
# Top 5 Pokémon:
# Name: ho-oh
# Sentiment Score: 1.0
# Total Stat: 680
#
# Name: zacian
# Sentiment Score: 1.0
# Total Stat: 660
#
# Name: florges
# Sentiment Score: 1.0
# Total Stat: 552
#
# Name: magmar
# Sentiment Score: 1.0
# Total Stat: 495
#
# Name: kabutops
# Sentiment Score: 1.0
# Total Stat: 495

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with columns 'name', 'ability', and 'total'.
# Replace 'df' with the actual name of your DataFrame.

def find_top_pokemon(df, num_top=10):
    # Sort the DataFrame by total stats (in descending order) and then by ability (in ascending order)
    sorted_df = df.sort_values(by=['total', 'abilities'], ascending=[False, True])

    # Get the information of the top Pokémon
    top_pokemon_info = sorted_df.iloc[:num_top]

    # Extract the relevant information for the top Pokémon
    top_pokemon_names = top_pokemon_info['name'].tolist()
    top_pokemon_abilities = top_pokemon_info['abilities'].tolist()
    top_pokemon_totals = top_pokemon_info['total'].tolist()

    return top_pokemon_names, top_pokemon_abilities, top_pokemon_totals

# Example usage to show the top 10 Pokémon
top_pokemon_names, top_pokemon_abilities, top_pokemon_totals = find_top_pokemon(df, num_top=10)

print("Top 10 Pokémon:")
for i in range(len(top_pokemon_names)):
    print(f"Name: {top_pokemon_names[i]}")
    print(f"Abilities: {top_pokemon_abilities[i]}")
    print(f"Total Stat: {top_pokemon_totals[i]}")
    print()
# Out:
# Top 10 Pokémon:
# Name: arceus
# Abilities: multitype
# Total Stat: 720
#
# Name: eternatus
# Abilities: pressure
# Total Stat: 690
#
# Name: rayquaza
# Abilities: air-lock
# Total Stat: 680
#
# Name: yveltal
# Abilities: dark-aura
# Total Stat: 680
#
# Name: xerneas
# Abilities: fairy-aura
# Total Stat: 680
#
# Name: solgaleo
# Abilities: full-metal-body
# Total Stat: 680
#
# Name: lugia
# Abilities: pressure multiscale
# Total Stat: 680
#
# Name: ho-oh
# Abilities: pressure regenerator
# Total Stat: 680
#
# Name: dialga
# Abilities: pressure telepathy
# Total Stat: 680
#
# Name: palkia
# Abilities: pressure telepathy
# Total Stat: 680

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.scatterplot (x= df['hp'], y = df['atk'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot (x= df['hp'], y = df['total'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot (x= df['weight'], y = df['speed'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
